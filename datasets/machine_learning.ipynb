# %% [markdown]
# ![SPARK Banner](https://i.imgur.com/3vCmTns.png)
#
# # SPARK | Day 4 | July 15th, 2021
#
# The agenda for today:
#
# 1. Machine Learning
# 2. Supervised Machine Learning (regression)
# 3. Unpervised Machine Learning (clustering)

# %% [markdown]
# # Maching Learning
#
# ## What is machine learning?
#
# Machine learning isn't really a well defined term. There are, however, two defintions that are well accepted
#
# ### Arthur Samuel (1959)
#     Field of study that gives computers the ability to learn without being explicitly programmed
#
# ### Tom Michel (1999)
#     A computer program is said to learn from experience E with respect to some class of tasks T and performance measure P, if its performance at tasks in T, as measured by P, improves with experience E
#
# ## Types of Machine Learning
# There are two major branches or machine learning that you different types of learning alorithms.
#
# ### 1. Superivised learning
# We teach a computer how to do something, then let is use its new found knowledge to do it.
#
# - supervised learning requires **labelled** data
# - e.g., regression, classification
#
# ### 2. Unsupervised learning
# We let the computer learn how to learn to do somethings, and use its knowledge to getermine structure and patterns in the data.
#
# - unsupervised learning requested **unlabelled** data
# - e.g., clustering

# %%
from IPython.display import HTML

HTML('<iframe width="560" height="315" src="https://youtu.be/f_uwKZIAeM0" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>')
# Out:
# <iframe width="560" height="315" src="https://youtu.be/f_uwKZIAeM0" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %% [markdown]
# ## Importing Machine Learning Libraries
#
# There are some specialized libraries in python that we can use for machine learning.
#
# ### Sklearn
#
# [Sklearn](https://scikit-learn.org/stable/) is a library of simple and efficient tools for machine learning problems like classification, regression and clustering.
#
# To import sklearn we use an import statement
#
# ```
#     import sklearn
# ```

# %%
# Lets import sklearn, along with our other data science packages

import numpy as np # For math- and matrix-based functions
import pandas as pd # For DataFrame functionality
import seaborn # For plotting/ data visualization
import sklearn # For machine learning

# %% [markdown]
# ## Load Data

# %%
## Load Data

# %%
df = pd.read_csv(r"C:\Users\nguye\Documents\GitHub\spark_shared_repo\datasets\hp_characters.csv", sep=";" )

df = df.drop(columns='Id')

df.set_index("Name").to_csv("hp_character_data.csv")

# %%
df
# Out:
#                                         Name  Gender  \
# 0                         Harry James Potter    Male
# 1                      Ronald Bilius Weasley    Male
# 2                      Hermione Jean Granger  Female
# 3    Albus Percival Wulfric Brian Dumbledore    Male
# 4                              Rubeus Hagrid    Male
# ..                                       ...     ...
# 135                 Wilhelmina Grubbly-Plank  Female
# 136                          Fenrir Greyback    Male
# 137                      Gellert Grindelwald    Male
# 138                                    Dobby    Male
# 139                                 Kreacher    Male
#
#                                                    Job       House  \
# 0                                              Student  Gryffindor
# 1                                              Student  Gryffindor
# 2                                              Student  Gryffindor
# ...
